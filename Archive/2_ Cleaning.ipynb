# %% [markdown]
# ## 0. Library

# %%
! pip install scikit-learn --user
! pip install textblob -- user

import pandas as pd
import os
# Out:
# Requirement already satisfied: scikit-learn in c:\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\python312\lib\site-packages (from scikit-learn) (2.1.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\python312\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: textblob in c:\users\jiaying\appdata\roaming\python\python312\site-packages (0.18.0.post0)
# ERROR: Could not find a version that satisfies the requirement user (from versions: none)
# ERROR: No matching distribution found for user
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Data Cleaning

# %%
def list_csv_files(directory):
    # List to hold csv file names
    csv_files = []
    
    # Iterate over files in the directory
    for filename in os.listdir(directory):
        # Check if the file is a CSV
        if filename.endswith('.csv'):
            csv_files.append(filename)
    
    return csv_files

folder_path = 'data'
csv_files = list_csv_files(folder_path)

# List to hold dataframes
combined = []

# Specify the required columns
required_columns = ['sender', 'receiver', 'date', 'subject', 'body', 'urls', 'label']

# Process each file
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    
    # Read with TREC-specific parameters if needed
    if 'TREC' in file:
        df = pd.read_csv(file_path, on_bad_lines="warn", lineterminator="\n")
    else:
        df = pd.read_csv(file_path)
    
    # Check if the dataset contains the required 7 columns
    if set(required_columns).issubset(df.columns):
        # Only select the required columns
        df = df[required_columns]
        combined.append(df)

# Concatenate all the dataframes into one
combined_df = pd.concat(combined, ignore_index=True)

# Print the combined dataframe details
print(f"Combined DataFrame Shape: {combined_df.shape}")
print(f"Columns: {combined_df.columns}")
# Out:
# Combined DataFrame Shape: (184843, 7)
# Columns: Index(['sender', 'receiver', 'date', 'subject', 'body', 'urls', 'label'], dtype='object')

# %%
# Remove rows with missing values in any of the columns
combined_df = combined_df.dropna()

# Print the shape of the cleaned DataFrame to confirm removal of missing values
print(f"Combined DataFrame Shape after removing missing values: {combined_df.shape}")
# Out:
# Combined DataFrame Shape after removing missing values: (174904, 7)

# %% [markdown]
# From EDA, we came to realise that most of the URLs in the dataset was labelled 0 or 1. Hence, for the small percentage of rows that contain actual URL strings, we converted them to 1 and 0 too.

# %%
def convert_urls(url_column_value):
    # If it's already "0" or "1" as a string, return as is
    if url_column_value == "0" or url_column_value == "1":
        return int(url_column_value)  # Convert to integer for consistency
    # If it's an empty list "[]", convert to 0
    elif url_column_value == "[]":
        return 0
    # If it's a non-empty list (e.g., "[http://example.com]"), convert to 1
    elif url_column_value.startswith("[") and url_column_value.endswith("]"):
        return 1
    return 0  # Default fallback if not recognized

# Convert the 'urls' column to strings
combined_df['urls'] = combined_df['urls'].astype(str)

# Apply the conversion function to the 'urls' column
combined_df['urls'] = combined_df['urls'].apply(convert_urls)

# %%
# Convert all columns to string except for 'date' and 'label'
combined_df = combined_df.astype({
    'sender': str,
    'receiver': str,
    'subject': str,
    'body': str,
    'urls': int,
    'label': int
})

# Convert 'date' column to datetime, using `errors='coerce'` to handle bad date strings
combined_df['date'] = pd.to_datetime(combined_df['date'], errors='coerce', utc=True)

# Remove rows where 'date' column is NaT (invalid date)
combined_df = combined_df.dropna(subset=['date'])

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# This is the feature engineering for the date column.

# %%
def is_business_hours(hour):
    return 9 <= hour < 17

def extract_date_features(df):
    features = pd.DataFrame()

    # Extract the day of the month
    features['date_day_of_month'] = df['date'].dt.day

    # Extract the month of the year
    features['date_month'] = df['date'].dt.month

    # Numerise the days of the week e.g. 0 = Monday, 6 = Sunday
    features['date_day_of_week'] = df['date'].dt.dayofweek 

    # Numerise the time of the day by the hour in 24 hour format
    features['date_hour_of_day'] = df['date'].dt.hour

    # Checks whether it is the weekend
    features['date_is_weekend'] = (df['date'].dt.dayofweek >= 5).astype(int)

    # Checks whether it is during business hour
    features['date_is_business_hours'] = (features['date_hour_of_day'].apply(is_business_hours)).astype(int)

    return features

phishing_date_features = extract_date_features(combined_df)
combined_df = pd.concat([combined_df.reset_index(drop=True), phishing_date_features.reset_index(drop=True)], axis=1)

# %% [markdown]
# Feature Engineering for subject

# %%
def extract_subject_features(df):
    features = pd.DataFrame()

    # Checks if the email is a reply to any previous mail
    features['subj_reply'] = (df['subject'].apply(lambda x: x.lower().startswith("re:"))).astype(int)

    # Checks if the email is a forward from another mail
    features['subj_forward'] = (df['subject'].apply(lambda x: x.lower().startswith("fwd:"))).astype(int)

    # Number of words in the subject
    features['subj_word_count'] = df['subject'].apply(lambda x: len(x.split()))

    # Number of characters in the subject
    features['subj_char_count'] = df['subject'].apply(lambda x: len(x))

    return features

# Extract subject features and add them to combined_df
subject_features = extract_subject_features(combined_df)
combined_df = pd.concat([combined_df.reset_index(drop=True), subject_features.reset_index(drop=True)], axis=1)

# %% [markdown]
# Feature Engineering for body

# %%
import pandas as pd
import re
from textblob import TextBlob
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Updated function to count the number of spam keywords in the body
def body_spam_count(body_content):
    spam_keywords = [
        "account", "access", "bank", "credit", "click", "identity", "inconvenience", "information", "limited",
        "log", "minutes", "password", "recently", "risk", "social", "security", "service", "suspended", "urgent", 
        "verify", "confirm", "locked", "unauthorized", "compromise", "refund", "billing", "update", "deactivate", 
        "subscription", "win", "prize", "offer", "discount", "reward", "free", "claim", "verify your account", 
        "reset password", "suspension", "fraud", "alert", "protection", "sign-in", "login", "activation", "urgent action"
    ]
    return sum(1 for word in body_content.lower().split() if word in spam_keywords)


# Feature engineering function
def extract_body_features(df):
    features = pd.DataFrame()
    
    # Basic text features
    features['body_char_count'] = df['body'].apply(len)
    features['body_word_count'] = df['body'].apply(lambda x: len(x.split()))
    features['body_distinct_word_count'] = df['body'].apply(lambda x: len(set(x.split())))
    features['body_average_word_length'] = features.apply(lambda row: row['body_char_count'] / row['body_word_count'] if row['body_word_count'] > 0 else 0, axis=1)

    # Uppercase and numeric characters
    features['body_uppercase_word_count'] = df['body'].apply(lambda x: sum(1 for word in x.split() if word.isupper()))
    features['body_numeric_char_count'] = df['body'].apply(lambda x: sum(c.isdigit() for c in x))

    # Punctuation features
    features['body_exclamation_count'] = df['body'].apply(lambda x: x.count('!'))
    features['body_question_count'] = df['body'].apply(lambda x: x.count('?'))
    features['body_special_char_count'] = df['body'].apply(lambda x: len(re.findall(r'[#$%&@]', x)))

    # Sentiment analysis
    features['body_sentiment_polarity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.polarity)
    features['body_sentiment_subjectivity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

    # URL analysis
    features['body_url_count'] = df['body'].apply(lambda x: len(re.findall(r'http[s]?://', x)))
    features['body_shortened_url_count'] = df['body'].apply(lambda x: len(re.findall(r'bit\.ly|t\.co|tinyurl', x)))

    # Spam count check
    features['body_spam_count'] = df['body'].apply(body_spam_count)
    
    return features

# Generate features
phishing_body_features = extract_body_features(combined_df)
combined_df = pd.concat([combined_df.reset_index(drop=True), phishing_body_features.reset_index(drop=True)], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 51
#      48     return features
#      50 # Generate features
# ---> 51 phishing_body_features = extract_body_features(combined_df)
#      52 combined_df = pd.concat([combined_df.reset_index(drop=True), phishing_body_features.reset_index(drop=True)], axis=1)
#
# Cell In[19], line 38, in extract_body_features(df)
#      35 features['body_special_char_count'] = df['body'].apply(lambda x: len(re.findall(r'[#$%&@]', x)))
#      37 # Sentiment analysis
# ---> 38 features['body_sentiment_polarity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.polarity)
#      39 features['body_sentiment_subjectivity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
#      41 # URL analysis
#
# File c:\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[19], line 38, in extract_body_features.<locals>.<lambda>(x)
#      35 features['body_special_char_count'] = df['body'].apply(lambda x: len(re.findall(r'[#$%&@]', x)))
#      37 # Sentiment analysis
# ---> 38 features['body_sentiment_polarity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.polarity)
#      39 features['body_sentiment_subjectivity'] = df['body'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
#      41 # URL analysis
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\decorators.py:23, in cached_property.__get__(self, obj, cls)
#      21 if obj is None:
#      22     return self
# ---> 23 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      24 return value
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\blob.py:439, in BaseBlob.sentiment(self)
#     430 @cached_property
#     431 def sentiment(self):
#     432     """Return a tuple of form (polarity, subjectivity ) where polarity
#     433     is a float within the range [-1.0, 1.0] and subjectivity is a float
#     434     within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is
#    (...)
#     437     :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     438     """
# --> 439     return self.analyzer.analyze(self.raw)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\en\sentiments.py:45, in PatternAnalyzer.analyze(self, text, keep_assessments)
#      43 else:
#      44     Sentiment = namedtuple("Sentiment", ["polarity", "subjectivity"])
# ---> 45     return Sentiment(*pattern_sentiment(text))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\_text.py:1001, in Sentiment.__call__(self, s, negation, **kwargs)
#     997 # A string of words.
#     998 # Sentiment("a horrible movie") => (-0.6, 1.0)
#     999 elif isinstance(s, basestring):
#    1000     a = self.assessments(
# -> 1001         ((w.lower(), None) for w in " ".join(self.tokenizer(s)).split()),
#    1002         negation,
#    1003     )
#    1004 # A pattern.en.Text.
#    1005 elif hasattr(s, "sentences"):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\_text.py:1445, in Parser.find_tokens(self, string, **kwargs)
#    1441 """Returns a list of sentences from the given string.
#    1442 Punctuation marks are separated from each word by a space.
#    1443 """
#    1444 # "The cat purs." => ["The cat purs ."]
# -> 1445 return find_tokens(
#    1446     str(string),
#    1447     punctuation=kwargs.get("punctuation", PUNCTUATION),
#    1448     abbreviations=kwargs.get("abbreviations", ABBREVIATIONS),
#    1449     replace=kwargs.get("replace", replacements),
#    1450     linebreak=r"\n{2,}",
#    1451 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\textblob\_text.py:442, in find_tokens(string, punctuation, abbreviations, replace, linebreak)
#     439 sentences = (" ".join(s) for s in sentences if len(s) > 0)
#     440 sentences = (RE_SARCASM.sub("(!)", s) for s in sentences)
#     441 sentences = [
# --> 442     RE_EMOTICONS.sub(lambda m: m.group(1).replace(" ", "") + m.group(2), s)
#     443     for s in sentences
#     444 ]
#     445 return sentences
#
# KeyboardInterrupt:

# %% [markdown]
# Feature Engineering for sender (Uses receiver too)

# %%
import pandas as pd
import re

def get_email_domain(email):
    """Helper function to extract the domain from an email address."""
    match = re.search(r'@([\w.-]+)', email)
    return match.group(1).lower() if match else None  # Normalize to lowercase

def send_diffSenderReceiver(send_address, receiver_addresses):
    """Check if sender domain is different from all receiver domains."""
    send_domain = get_email_domain(send_address)

    # Split receiver addresses and get their domains
    receiver_domains = [
        get_email_domain(receiver) for receiver in receiver_addresses.split(',')
    ]
    
    # Remove None values and normalize to lowercase
    receiver_domains = [domain.lower() for domain in receiver_domains if domain]

    # Check if any receiver domain is different from sender domain
    if send_domain and receiver_domains:
        return not all(domain == send_domain for domain in receiver_domains)  # Return True if any domain is different

    return False  # If sender or receiver domains are invalid, return False

# Functions to extract sender address based attributes
def extract_sender_features(df):
    features = pd.DataFrame()

    # Integer: number of words in sender address
    features['send_word_count'] = df['sender'].apply(lambda x: len(x.split()))

    # Integer: number of characters in sender address
    features['send_char_count'] = df['sender'].apply(lambda x: len(x))

    # Boolean: check if sender domain is different from all receiver domains
    features['send_diffSenderReceiver'] = (df.apply(
        lambda row: send_diffSenderReceiver(row['sender'], row['receiver']), axis=1
    )).astype(int)

    return features

# Extract features and add to combined_df
features = extract_sender_features(combined_df)
combined_df = pd.concat([combined_df.reset_index(drop=True), features.reset_index(drop=True)], axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# List of columns to exclude from scaling
excluded_columns = ['sender', 'receiver', 'date', 'subject', 'body', 'urls', 'label', 
                    'date_is_weekend', 'date_is_business_hours', 'subj_reply', 
                    'subj_forward', 'send_diffSenderReceiver']

# List of columns to scale (those that are not in the excluded list)
scaled_columns = [col for col in combined_df.columns if col not in excluded_columns]

# Scale the selected columns
combined_df[scaled_columns] = scaler.fit_transform(combined_df[scaled_columns])

# Check the modified DataFrame
combined_df.head(50)
# Out:
#                                                sender  \
# 0                  "Hu, Sylvia" <Sylvia.Hu@ENRON.com>
# 1                    "Webb, Jay" <Jay.Webb@ENRON.com>
# 2                "Symms, Mark" <Mark.Symms@ENRON.com>
# 3              "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 4   "Williams, Jason R (Credit)" <Jason.R.Williams...
# 5              "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 6          "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 7                    "Shah, Kal" <Kal.Shah@ENRON.com>
# 8                    "Shah, Kal" <Kal.Shah@ENRON.com>
# 9          "Gimble, Mathew" <Mathew.Gimble@ENRON.com>
# 10             "Newgard, Jim" <Jim.Newgard@ENRON.com>
# 11    "Thorn, Terence H." <Terence.H.Thorn@ENRON.com>
# 12  "Edison, Deborah J." <Deborah.J.Edison@ENRON.com>
# 13  "Barkowsky, Gloria G." <Gloria.G.Barkowsky@ENR...
# 14  "Kozadinos, Tracey" <Tracey.Florio-Kozadinos@E...
# 15                                 KTracey111@aol.com
# 16           "Johnson, Rick" <Rick.Johnson@ENRON.com>
# 17               "Owen, David" <David.Owen@ENRON.com>
# 18           "Gordon, D'Ann" <D'Ann.Gordon@ENRON.com>
# 19   "Rorschach, Reagan" <Reagan.Rorschach@ENRON.com>
# 20                 "Hu, Sylvia" <Sylvia.Hu@ENRON.com>
# 21         "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 22     "Johnson, Patrick" <Patrick.Johnson@ENRON.com>
# 23         "Hayman, Kendra" <kendra.hayman@ENRON.com>
# 24         "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 25             "Lewchuk, Ken" <Ken.Lewchuk@ENRON.com>
# 26           "Melodick, Kim" <Kim.Melodick@ENRON.com>
# 27                 "Boyt, Eric" <Eric.Boyt@ENRON.com>
# 28               "Cooley, Jan" <Jan.Cooley@ENRON.com>
# 29   "Schroeder, Maggie" <Maggie.Schroeder@ENRON.com>
# 30  "Villarreal, Lillian" <Lillian.Villarreal@ENRO...
# 31       "Holtzman, Staci" <Staci.Holtzman@ENRON.com>
# 32             "Alport, Kysa" <Kysa.Alport@ENRON.com>
# 33             "Scott, Susan" <Susan.Scott@ENRON.com>
# 34         "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 35              "Bump, Dan J." <Dan.J.Bump@ENRON.com>
# 36  "Williams, Robert C." <Robert.C.Williams@ENRON...
# 37  "Williams, Robert C." <Robert.C.Williams@ENRON...
# 38           "Melodick, Kim" <Kim.Melodick@ENRON.com>
# 39               "Smith, Will" <Will.Smith@ENRON.com>
# 40       "Brownfeld, Gail" <Gail.Brownfeld@ENRON.com>
# 41                   "Tu, Denis" <Denis.Tu@ENRON.com>
# 42  "Kozadinos, Tracey" <Tracey.Florio-Kozadinos@E...
# 43              "Almeida, Keoni" <KAlmeida@caiso.com>
# 44  "Kozadinos, Tracey" <Tracey.Florio-Kozadinos@E...
# 45      "Foster, Chris H." <Chris.H.Foster@ENRON.com>
# 46         EDIS Email Service <edismail@incident.com>
# 47         "Hilgert, Chris" <Chris.Hilgert@ENRON.com>
# 48                      Suzie Stone <sistone@bpa.gov>
# 49         EDIS Email Service <edismail@incident.com>
#
#                                              receiver  \
# 0   "Acevedo, Felecia" <Felecia.Acevedo@ENRON.com>...
# 1            "Lambie, Chris" <Chris.Lambie@ENRON.com>
# 2         "Thomas, Paul D." <Paul.D.Thomas@ENRON.com>
# 3   "Grass, John" <John.Grass@ENRON.com>, "Nemec, ...
# 4   "Nemec, Gerald" <Gerald.Nemec@ENRON.com>, "Dic...
# 5   "Hodge, Jeffrey T." <Jeffrey.T.Hodge@ENRON.com...
# 6   "Dushinske, John" <John.Dushinske@ENRON.com>, ...
# 7    "Taylor, Mark E (Legal)" <Mark.Taylor@ENRON.com>
# 8    "Taylor, Mark E (Legal)" <Mark.Taylor@ENRON.com>
# 9   "Weldon, V. Charles" <V.Charles.Weldon@ENRON.c...
# 10  "Fastow, Andrew" <Andrew.Fastow@ENRON.com>, "S...
# 11           "Hayslett, Rod" <Rod.Hayslett@ENRON.com>
# 12  "Buy, Rick" <Rick.Buy@ENRON.com>, "Fox, Craig ...
# 13      "Farmer, Daren J." <Daren.J.Farmer@ENRON.com>
# 14  "Johnson, Shawna" <Shawna.Johnson@ENRON.com>, ...
# 15  "Baughman Jr., Don" <Don.Baughman@ENRON.com>, ...
# 16  "Barrow, Cynthia" <Cynthia.Barrow@ENRON.com>, ...
# 17     "Johnson, Patrick" <Patrick.Johnson@ENRON.com>
# 18  "Austin, Terri" <Terri.Austin@ENRON.com>, "Bla...
# 19                   "Mann, Kay" <Kay.Mann@enron.com>
# 20  "Acevedo, Felecia" <Felecia.Acevedo@ENRON.com>...
# 21  "Barker, Courtney" <Courtney.Barker@ENRON.com>...
# 22  "Nemec, Gerald" <Gerald.Nemec@ENRON.com>, "Gra...
# 23  "Bike, Anne" <Anne.Bike@ENRON.com>, "Frank, Ca...
# 24  "Chavez, Gabriel" <Gabriel.Chavez@ENRON.com>, ...
# 25         "Stokley, Chris" <Chris.Stokley@ENRON.com>
# 26         "Benson, Robert" <Robert.Benson@ENRON.com>
# 27    "Hodge, Jeffrey T." <Jeffrey.T.Hodge@ENRON.com>
# 28  mday@gmssr.com, wcp@quinnemanuel.com, "McCullo...
# 29           "Hayslett, Rod" <Rod.Hayslett@ENRON.com>
# 30  "Alvarez, Gloria" <Gloria.Alvarez@ENRON.com>, ...
# 31           "Nemec, Gerald" <Gerald.Nemec@ENRON.com>
# 32  "Alonso, Tom" <Tom.Alonso@ENRON.com>, "Badeer,...
# 33  "Tapscott, Ron" <Ron.Tapscott@ENRON.com>, "Wil...
# 34  "Barker, Courtney" <Courtney.Barker@ENRON.com>...
# 48 2001-07-03 18:35:04+00:00
# 49 2001-07-03 18:47:25+00:00
#
#                                               subject  \
# 0         FW: June 29 -- BNA, Inc. Daily Labor Report
# 1                                  NGX failover plan.
# 2                                   RE: Intranet Site
# 3                FW: ENA Upstream Company information
# 4                                 New Master Physical
# 5                FW: ENA Upstream Company/Mirant GISB
# 6   PG&E GT-NW Receives Open Season Requests Total...
# 7                      Internet Advertising agreement
# 8                  FW: Internet Advertising agreement
# 9                                    FMPA Oil Invoice
# 10                                       Smith Graham
# 11                                              SABIC
# 12             FW: Mariner Management Meeting Minutes
# 13                                           RE: EPGT
# 14                                     RE: Surprise!!
# 15                           Fwd: Truly Irish........
# 16           Policy Narrative # 7 - Background checks
# 17                                     RE: LRCI tract
# 18  Project Status Report for the week of July 2, ...
# 19                                      FW: Enron EMA
# 20         FW: July 2 -- BNA, Inc. Daily Labor Report
# 21  FW: Western Energy--Fundamentals and Regulatio...
# 22                           FW: FW: Enron Tract 113A
# 23                                   Updated C/P list
# 24                                       Alaskan Info
# 25                                Sample Data Request
# 26  RE: List of Accomplishments-immediate action r...
# 27        PanNat Value - Confidential and Proprietary
# 28                                  Termination Right
# 29                                      Maggie's info
# 30                                 Enron Kids Meeting
# 31             Amended Compression Services Agreement
# 32                          EOL Data for July 2, 2001
# 33  Entergy -- credits for network upgrades  (ER01...
# 34  Kern River Expansion Completed Ahead of Schedule
# 35                                     Fishin' Report
# 36  FW: Request for Confidential Information from ...
# 37               RE: Status report regarding subpenas
# 38                                    accomplishments
# 39                             Pre Schedule Workspace
# 40         FW: New Intelligence re IRS and "Capacity"
# 41                               Summer Vacation Plan
# 42    Cougars@Enron  - New Interim Dean Named for CBA
# 43                        RE: Enron 480, 1480 charges
# 44                      Cougars@Enron UH Alumni Group
# 45                                   FW: New Gas Deal
# 46  [EDIS]  STAGE 1 ELECTRICAL EMERGENCY DECLARED ...
# 47                Enron Compression Services Proposal
# 48  OASIS Posting - 07-03-01 Energy  Index for Gen...
# 49  [EDIS]  STAGE 2 ELECTRICAL EMERGENCY DECLARED ...
#
#                                                  body  urls  label  \
# 0   User ID:  enrondlr\nPW:        bnaweb22\n\n\n ...     1      0
# 1   \nHi Chris,  \n\nTonight we are rolling out a ...     0      0
# 2   Rika r these new?\n\n -----Original Message---...     1      0
# 3   John/Gerald,\n\nWe are currently trading under...     0      0
# 4   Gerald and Stacy -\n\nAttached is a worksheet ...     0      0
# 5   FYI. Below is a copy of my communication with ...     0      0
# 6   PG&E GT-NW Plans Lateral Across Washington Sta...     0      0
# 7   Mark -- I am working with the East power desk ...     0      0
# 8   oops.  here it is.\n\nkal\n \n\n\n\n -----Orig...     0      0
# 9   Mark and Charlie,\n\nFMPA is ready to bill us ...     0      0
# 10  Please note that the Enron Cash Balance Plan h...     0      0
# 11  Rod-Many thanks for helping me out with SABIC....     0      0
# 12  \n\n -----Original Message-----\nFrom: \t"Cagl...     0      0
# 13  Daren - what about February 2000?  It doesn't ...     0      0
# 14  Hi, Shawna.\n\nI have a new position with Enro...     1      0
# 15  \n\nReturn-path: <Comein63@aol.com>\nFrom: Com...     1      0
# 16  Attached is draft 0 of a policy narrative on b...     0      0
# 17  \n\tPat,\n\n\tI suggest asking Gerald Nemec fo...     0      0
# 18  Hello Everyone,\n\nHere is the PSR for the wee...     0      0
# 19  \n\nReagan C. Rorschach\nEnron North America\n...     0      0
# 20  \nUser ID:  enrondlr\nPW:        bnaweb22\n\n ...     1      0
# 21  CERA's monthly briefing is on the Western Mark...     1      0
# 22  \n\n -----Original Message-----\nFrom: \tJohns...     0      0
# 23  Hey guys, \nHere is the new updated counterpar...     0      0
# 24  Note:  I had been sending the Arctic market in...     0      0
# 25  Chris,\n\nWe have contacted Pat Priestley rega...     0      0
# 26  Thanks a million!\n\n -----Original Message---...     0      0
# 27  Jeff,\n\nPer your request, below is the value ...     0      0
# 28  The telephone conference that was scheduled to...     0      0
# 29  My Dad's name was Samuel Lewis Paull\n\n\nIf a...     0      0
# 30  \nWelcome to all of the new Enron Kids volunte...     0      0
# 31  Gerald -  \n\nWhere we are on getting the amen...     0      0
# 32  EOL Deals\t From: 7/1/2001   To: 7/2/2001\t \t...     0      0
# 33  Last week FERC issued an order conditionally a...     0      0
# 34  Williams Completes 2001 Kern River Expansion A...     1      0
# 35  For all you fishermen, see the link below:\n\n...     1      0
# 36  \n\n -----Original Message-----\nFrom: \tBenev...     0      0
# 37  Michael, Jan Cooley is compiling a list of inh...     1      0
# 38  Here are your typed accomplishments for your f...     0      0
# 39  Cara,\n\nI fixed the locking problem on the Bu...     0      0
# 40  Please take a look at the attached and give me...     1      0
# 41  I plan to take July 27 (Friday) P.M. through A...     0      0
# 42  Rod,\nI wanted to forward this to you.  Arthur...     1      0
# 43  \nI confirmed that since Enron does not deviat...     0      0
# 44  Good afternoon.\n\nI wanted to forward you one...     1      0
# 45  Kim:\n\nHere is a summary of the structure we ...     0      0
# 46  From: ISO\n\nISO declared STAGE 1 Electrical E...     1      0
# 47  Andy,\n\nPer our recent discussions, you will ...     0      0
# 48  Please click on the attached icon or the Web a...     1      0
# 49  From: ISO\n\nISO declared STAGE 2 Electrical E...     1      0
#
#     date_day_of_month  date_month  date_day_of_week  ...  body_question_count  \
# 0            1.725612   -0.235795          0.845494  ...            -0.148146
# 1            1.725612   -0.235795          0.845494  ...            -0.148146
# 2            1.725612   -0.235795          0.845494  ...            -0.047293
# 3            1.725612   -0.235795          0.845494  ...            -0.047293
# 4            1.725612   -0.235795          0.845494  ...            -0.148146
# 5            1.725612   -0.235795          0.845494  ...            -0.148146
# 6            1.725612   -0.235795          0.845494  ...            -0.148146
# 7            1.725612   -0.235795          0.845494  ...            -0.047293
# 8            1.725612   -0.235795          0.845494  ...            -0.047293
# 9            1.725612   -0.235795          0.845494  ...            -0.148146
# 10           1.725612   -0.235795          0.845494  ...            -0.148146
# 11           1.725612   -0.235795          0.845494  ...            -0.148146
# 20                 0.060489                -0.381722
# 21                -0.020772                -0.286333
# 22                 0.054238                 0.191263
# 23                -0.033274                -0.016933
# 24                 0.010482                 0.192401
# 25                -0.033274                -0.764241
# 26                -0.014521                -0.398384
# 27                -0.027023                -0.764241
# 28                -0.033274                -0.764241
# 29                -0.033274                -0.642457
# 30                -0.020772                 0.288218
# 31                -0.033274                 0.514486
# 32                 0.060489                -0.560074
# 33                -0.033274                 0.263308
# 34                -0.033274                 0.276109
# 35                -0.033274                -0.764241
# 36                 0.266768                -0.373337
# 37                 0.004231                -0.506538
# 38                -0.033274                -0.764241
# 39                -0.033274                 0.331811
# 40                 0.041737                -0.387819
# 41                -0.033274                -0.764241
# 42                -0.020772                 0.812970
# 43                 0.004231                 0.215563
# 44                 0.010482                 0.874552
# 45                -0.020772                -0.110692
# 46                -0.027023                 0.023546
# 47                -0.020772                 0.217224
# 48                -0.033274                 0.605824
# 49                -0.027023                 0.023546
#
#     body_sentiment_subjectivity  body_url_count  body_shortened_url_count  \
# 0                     -0.108630        5.465202                 -0.033873
# 1                     -0.267096       -0.231379                 -0.033873
# 2                     -0.764598        0.185444                 -0.033873
# 3                     -0.277870       -0.231379                 -0.033873
# 4                     -0.615755       -0.231379                 -0.033873
# 5                      0.370467       -0.231379                  1.072577
# 6                     -0.570758       -0.231379                 -0.033873
# 7                      0.586181       -0.231379                 -0.033873
# 8                      0.330133       -0.231379                 -0.033873
# 9                     -0.250383       -0.231379                 -0.033873
# 10                    -0.068729       -0.231379                 -0.033873
# 11                     0.454124       -0.231379                 -0.033873
# 12                     0.475038       -0.231379                 -0.033873
# 13                     0.079571       -0.231379                 -0.033873
# 14                     0.157904        0.046503                 -0.033873
# 15                    -0.512542        0.046503                 -0.033873
# 16                    -1.239918       -0.231379                 -0.033873
# 17                    -0.403354       -0.231379                 -0.033873
# 18                    -2.243795       -0.231379                 -0.033873
# 19                     0.412295       -0.231379                 -0.033873
# 20                    -0.210233        9.911314                 -0.033873
# 21                    -0.439267        0.324385                 -0.033873
# 22                     0.195214       -0.231379                 -0.033873
# 23                     0.037743       -0.231379                 -0.033873
# 24                    -0.113466       -0.231379                 -0.033873
# 25                    -1.598445       -0.231379                 -0.033873
# 26                    -0.208765       -0.231379                 -0.033873
# 27                    -2.132253       -0.231379                 -0.033873
# 28                    -1.302660       -0.231379                 -0.033873
# 29                    -1.016834       -0.231379                 -0.033873
# 30                    -0.097248       -0.231379                 -0.033873
# 31                    -0.310403       -0.231379                 -0.033873
# 32                     0.108426       -0.231379                 -0.033873
# 33                    -0.717066       -0.231379                 -0.033873
# 34                     0.419425       -0.092438                 -0.033873
# 35                    -2.243795       -0.092438                 -0.033873
# 36                    -0.132965       -0.231379                 -0.033873
# 37                    -0.429293       -0.092438                 -0.033873
# 38                    -2.243795       -0.231379                 -0.033873
# 39                    -0.382440       -0.231379                 -0.033873
# 40                    -0.302343        0.046503                 -0.033873
# 41                    -2.243795       -0.231379                 -0.033873
